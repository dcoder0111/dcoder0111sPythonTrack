# %% [markdown]
# <a href="https://colab.research.google.com/github/freezingMonkeys/freezingMonkeysPythonTrack/blob/main/NikeShoes_homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>HTML Web Scraping: Nike Example Homework 👟</h1>
# <h2>In the following activity, we will convert the collected data into a dataframe and analyse the data. </h2>

# %%
import requests
from bs4 import BeautifulSoup as soup
url = 'https://www.nike.com.hk/man/basketball/shoe/list.htm?intpromo=PETP'
page = requests.get(url).content
soup_page = soup(page,'html')
shoes = soup_page.findAll('dl', {'class': 'product_list_content'})
for shoe in range(len(shoes)):
  print(shoes[shoe].findAll('span', {'class': 'up'})[0].text + ": "+ shoes[shoe].findAll('dd', {'class': 'color666'})[0].text)
  print()

# %% [markdown]
# This is the code from our last activity.

# %% [markdown]
# Your homework is to figure out how to add all of these into a PANDAS frame, like this.
#
# ![Screenshot 2021-06-28 at 2.50.36 PM.png](data:image/png;base64,...)

# %% [markdown]
# Obviously there are more rows but thats the overall concept.

# %% [markdown]
# <h1>Tip: Check out the Pandas notebook</h1>
# <h2></h2>

# %%
import pandas as pd 
# YOUR CODE HERE!
# tip: use for loops to create lists of the names and prices then create a dictionary using those lists,
#      then use those lists to create a pandas dataframe
# challenge: I used less than 10 lines of code, try to beat that!

# %% [markdown]
# <h1>Challenge! Create anothe column in the DataFrame for integer prices so it will be easier to analyse</h1>
#
# Tip: Use lambdas! (you can search it up for the definition), and remember to cast the price to be an int :)

# %%
# YOUR CODE HERE!

# %% [markdown]
# The end results should look like this:
# ![Screenshot 2021-06-28 at 2.49.05 PM.png](data:image/png;base64,...)
